# %% [markdown]
# ### Environment

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# ### Libraries

# %%
import re

# %%
import networkx as nx
import pandas as pd

# %% [markdown]
# ### Plotting configuration

# %%
matplotlib.rcParams['figure.figsize'] = (12, 7)
matplotlib.rcParams.update({'figure.autolayout': True})

# %% [markdown]
# ### Definitions

# %%
# Attribute dictionary
a = {
    # schema
    'type': u'[Schema] Type', # node type
    'label': u'label', # relationship name
    # node types
    'action': u'Action',
    'character': u'Character',
    'family': u'Family',
    'object': u'Object',
    'painting': u'Painting',
    'setting': u'Setting',
    #relation labels
    'associated': u'associated with',
    'depict': u'depict',
    'depicts': u'depicts',
    'has': u'has',
    # node attributes
    'casta': u'(Character) Casta',
    'child': u'(Character) Progeny',
    'character_title': u'(Character) Title',
    'inscription': u'(Painting) Incription',
    'male': u'(Character) Male',
    'female': u'(Character) Female',
    'family_title': u'(Family) Title',
    'parent': u'(Character) Parent',
    # relation attributes
    'doing': u'doing',
    'receiving': u'received by',
    # values
    'espanol': u'Espa\xf1ol ',
    'true': u'True',
    'fighting': u'Hitting/Fighting',
    'non-fighting': u'Fighting - non-physical',
    'crying': u'Crying/upset/pleading',
}

# %% [markdown]
# ### Auxiliar methods

# %%
def to_unicode(s):
    result = s
    if type(s) != unicode:
        result = s.decode('utf-8')
    return result

def equalize_dict(keys, data_dict):
    for key in keys:
        if key not in data_dict:
            data_dict[key] = 0
    return data_dict

# %% [markdown]
# ### Functions

# %%
def node_dict_by_type(nbunch):
    typ = a['type']
    
    nodes = {}
    if type(nbunch) == nx.classes.multidigraph.DiGraph:
        nbunch = nbunch.nodes_iter(data=True)
    for node, attrs in nbunch:
        node_type = attrs[typ]
        nodes.setdefault(node_type, [])
        nodes[node_type].append((node, attrs))
    return nodes

def node_dict_by_attr(nbunch, attr):
    nodes = {}
    if type(nbunch) == nx.classes.multidigraph.DiGraph:
        nbunch = nbunch.nodes_iter(data=True)
    for node, attrs in nbunch:
        if attr in attrs:
            value = attrs[attr]
            nodes.setdefault(value, [])
            nodes[value].append((node, attrs))
    return nodes

def freq_dict(nbunch):
    freqs = {}
    for key in nbunch.iterkeys():
        freqs[key] = len(nbunch[key])
    return freqs

def node_neighbor_list(node, graph, attr=None, value=None, label=None, typ=None):
    if attr and value:
        value = to_unicode(value)
    neighbors = []
    relations = graph[node]
    if label:
        relations = filter_relations_by_label(relations, label)
    if typ:
        relations = filter_relations_by_type(graph, relations, typ)
    neighbors_attrs = [(n, graph.node[n]) for n in relations]
    for neighbor_attrs in neighbors_attrs:
        attrs = neighbor_attrs[1]
        if attr and value:
            if attr in attrs:
                val = attrs[attr]
                val = to_unicode(val)
                if val == value:
                    neighbors.append(neighbor_attrs)
        else:
            neighbors.append(neighbor_attrs)
    return neighbors

def filter_node_dict_by_value(nbunch, attr, value):
    nodes = []
    if type(nbunch) == nx.classes.multidigraph.DiGraph:
        nbunch = nbunch.nodes_iter(data=True)
    for node, attrs in nbunch:
        if attr in attrs:
            val = attrs[attr]
            if val == value:
                nodes.append((node, attrs))
    return nodes

def filter_relations_by_label(relations, label_value):
    label_name = a['label']
    
    relations_aux = {}
    for node, attrs in relations.iteritems():
        if label_name in attrs and attrs[label_name] == label_value:
            relations_aux[node] = attrs
    return relations_aux

def filter_relations_by_type(graph, relations, type_value):
    type_name = a['type']
    
    relations_aux = {}
    for node, attrs in relations.iteritems():
        node_attrs = graph.node[node]
        if type_name in node_attrs and node_attrs[type_name] == type_value:
            relations_aux[node] = attrs
    return relations_aux

# %% [markdown]
# ### Graph

# %%
castas = nx.read_gexf('castas.gexf')

# %% [markdown]
# ### Characters by casta

# %%
characters = node_dict_by_type(castas)[a['character']]
characters_by_casta = node_dict_by_attr(characters, a['casta'])
freq_characters_by_casta = freq_dict(characters_by_casta)

# %%
characters_by_casta_sr = pd.Series(freq_characters_by_casta)
characters_by_casta_sr.plot(kind='bar')
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/figure.py:1533: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### Spaniards by receiving action

# %%
spaniards_by_receiving_action = {}
actions = map(lambda x: x[0], node_dict_by_type(castas)[a['action']])
for action in actions:
    spanish_neighbors = node_neighbor_list(
        action,
        castas,
        attr=a['casta'],
        value=a['espanol'],
        label=a['receiving'],
    )
    label = castas.node[action][a['label']]
    spaniards_by_receiving_action[label] = spanish_neighbors
freq_spaniards_by_receiving_action = freq_dict(spaniards_by_receiving_action)

# %%
spaniards_by_receiving_action_sr = pd.Series(freq_spaniards_by_receiving_action)
spaniards_by_receiving_action_sr.plot(kind='bar')

# %% [markdown]
# ### Spaniards by doing action

# %%
spaniards_by_doing_action = {}
spaniards = characters_by_casta[a['espanol']]
for spaniard in spaniards:
    action_neighbors = node_neighbor_list(
        spaniard[0],
        castas,
        label=a['doing'],
    )
    for action in action_neighbors:
        label = action[1][a['label']]
        spaniards_by_doing_action.setdefault(label, [])
        spaniards_by_doing_action[label].append(spaniard)
freq_spaniards_by_doing_action = freq_dict(spaniards_by_doing_action)
actions = map(lambda x: x[1][a['label']], node_dict_by_type(castas)[a['action']])
freq_spaniards_by_doing_action = equalize_dict(actions, freq_spaniards_by_doing_action)

# %%
spaniards_by_doing_action_sr = pd.Series(freq_spaniards_by_doing_action)
spaniards_by_doing_action_sr.plot(kind='bar')

# %% [markdown]
# ### Male/Famale spaniards by doing action

# %%
male_spaniards = filter_node_dict_by_value(spaniards, a['male'], a['true'])
male_spaniards_by_doing_action = {}
for spaniard in male_spaniards:
    action_neighbors = node_neighbor_list(
        spaniard[0],
        castas,
        label=a['doing'],
    )
    for action in action_neighbors:
        label = action[1][a['label']]
        male_spaniards_by_doing_action.setdefault(label, [])
        male_spaniards_by_doing_action[label].append(spaniard)
male_freq_spaniards_by_doing_action = freq_dict(male_spaniards_by_doing_action)
actions = map(lambda x: x[1][a['label']], node_dict_by_type(castas)[a['action']])
male_freq_spaniards_by_doing_action = equalize_dict(actions, male_freq_spaniards_by_doing_action)

# %%
female_spaniards = filter_node_dict_by_value(spaniards, a['female'], a['true'])
female_spaniards_by_doing_action = {}
for spaniard in female_spaniards:
    action_neighbors = node_neighbor_list(
        spaniard[0],
        castas,
        label=a['doing'],
    )
    for action in action_neighbors:
        label = action[1][a['label']]
        female_spaniards_by_doing_action.setdefault(label, [])
        female_spaniards_by_doing_action[label].append(spaniard)
female_freq_spaniards_by_doing_action = freq_dict(female_spaniards_by_doing_action)
actions = map(lambda x: x[1][a['label']], node_dict_by_type(castas)[a['action']])
female_freq_spaniards_by_doing_action = equalize_dict(actions, female_freq_spaniards_by_doing_action)

# %%
male_spaniards_by_doing_action_sr = pd.Series(male_freq_spaniards_by_doing_action)
female_spaniards_by_doing_action_sr = pd.Series(female_freq_spaniards_by_doing_action)
male_female_spaniards_by_doing_action_df = pd.DataFrame({
    'male': male_spaniards_by_doing_action_sr,
    'female': female_spaniards_by_doing_action_sr,
})
male_female_spaniards_by_doing_action_df.plot(kind='bar')

# %% [markdown]
# ### Total spaniards by doing action

# %%
total_spaniards_by_doing_action_df = pd.DataFrame({
    'male': male_spaniards_by_doing_action_sr,
    'female': female_spaniards_by_doing_action_sr,
    'total': spaniards_by_doing_action_sr,
})
total_spaniards_by_doing_action_df.plot(kind='bar')

# %% [markdown]
# ### Paintings by setting

# %%
paintings = node_dict_by_type(castas)[a['painting']]

# %%
paintings_by_setting = {}
for painting in paintings:
    setting_neighbors = node_neighbor_list(
        painting[0],
        castas,
        label=a['depict'],
        typ=a['setting']
    )
    for setting in setting_neighbors:
        label = setting[1][a['label']]
        paintings_by_setting.setdefault(label, [])
        paintings_by_setting[label].append(painting)
freq_paintings_by_setting = freq_dict(paintings_by_setting)
settings = map(lambda x: x[1][a['label']], node_dict_by_type(castas)[a['setting']])
freq_paintings_by_setting = equalize_dict(settings, freq_paintings_by_setting)

# %%
paintings_by_setting_sr = pd.Series(freq_paintings_by_setting)
paintings_by_setting_sr.plot(kind='bar')

# %% [markdown]
# ### Spaniards by settings

# %%
spaniards_by_setting = {}
for setting in paintings_by_setting:
    paintings = paintings_by_setting[setting]
    for painting in paintings:
        spanish_neighbors = node_neighbor_list(
            painting[0],
            castas,
            attr=a['casta'],
            value=a['espanol'],
            label=a['depicts'],
            typ=a['character'],
        )
        spaniards_by_setting.setdefault(setting, [])
        for spaniard in spanish_neighbors:
            spaniards_by_setting[setting].append((spaniard[0], castas.node[spaniard[0]]))
freq_spaniards_by_setting = freq_dict(spaniards_by_setting)
settings = map(lambda x: x[1][a['label']], node_dict_by_type(castas)[a['setting']])
freq_spaniards_by_setting = equalize_dict(settings, freq_spaniards_by_setting)

# %%
spaniards_by_setting_sr = pd.Series(freq_spaniards_by_setting)
spaniards_by_setting_sr.plot(kind='bar')

# %% [markdown]
# ### Counting all characters and percentage of Spaniards as parents and as children

# %%
spaniards = characters_by_casta[a['espanol']]
spanish_parents = node_dict_by_attr(spaniards, a['parent'])[a['true']]
spanish_children = node_dict_by_attr(spaniards, a['child'])[a['true']]
total_others = len(characters) - len(spaniards)
total_spanish_parents = len(spanish_parents)
total_spanish_children = len(spanish_children)
freq_spaniards = {
    'Other castas': total_others,
    'Spanish parents': total_spanish_parents,
    'Spanish children': total_spanish_children
}

# %%
figure(1, figsize=(6,6))
spaniards_and_others_sr = pd.Series(freq_spaniards)
plt.pie(spaniards_and_others_sr, labels=spaniards_and_others_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=['c','g','r'])
# Out:
# ([<matplotlib.patches.Wedge at 0x3c4d510>,
#   <matplotlib.patches.Wedge at 0x3c44050>,
#   <matplotlib.patches.Wedge at 0x3c44a10>],
#  [<matplotlib.text.Text at 0x3c4dd10>,
#   <matplotlib.text.Text at 0x3c44750>,
#   <matplotlib.text.Text at 0x3b8ef50>],
#  [<matplotlib.text.Text at 0x3c4df50>,
#   <matplotlib.text.Text at 0x3c44990>,
#   <matplotlib.text.Text at 0x3b8ecd0>])

# %%
total_others
# Out:
# 953

# %%
total_spanish_parents
# Out:
# 185

# %%
total_spanish_children
# Out:
# 26

# %% [markdown]
# ### Number in title associated with Spaniards

# %%
num_re = r'(?P<number>\d+)'
num_comp = re.compile(num_re)
def get_number(inscription):
    result = num_comp.search(inscription)
    if result:
        number = int(result.group('number'))
    else:
        number = 'Inscription with no number'
    return number

# %%
numbers = {}
paintings = node_dict_by_type(castas)[a['painting']]
for painting in paintings:
    spanish_neighbors = node_neighbor_list(
        painting[0],
        castas,
        attr=a['casta'],
        value=a['espanol'],
        label=a['depicts'],
        typ=a['character'],
    )
    if spanish_neighbors:
        inscription = painting[1][a['inscription']]
        if inscription:
            number = get_number(inscription)
        else:
            number = 'No inscription in the painting'
        numbers[number] = numbers.get(number, 0) + 1

# %%
numbers_associated_with_spaniards_sr = pd.Series(numbers)
numbers_associated_with_spaniards_sr.plot(kind='bar')

# %% [markdown]
# ### Characters by family

# %%
characters_by_family = {}
fams = map(lambda x: x[0], node_dict_by_type(castas)[a['family']])
for fam in fams:
    character_neighbors = node_neighbor_list(
        fam,
        castas,
        label=a['has'],
        typ=a['character'],
    )
    label = castas.node[fam][a['label']]
    characters_by_family[label] = character_neighbors
freq_characters_by_family = freq_dict(characters_by_family)

# %%
figure(1, figsize=(20,10))
characters_by_family_sr = pd.Series(freq_characters_by_family)
characters_by_family_sr.plot(kind='bar')

# %% [markdown]
# ### Family most belonging to by casta

# %%
families_by_casta = {}
families = node_dict_by_type(castas)[a['family']]
all_castas = characters_by_casta.keys()
for casta in all_castas:
    characters_by_family = {}
    for family in families:
        character_neighbors = node_neighbor_list(
            family[0],
            castas,
            attr=a['casta'],
            value=casta,
            label=a['has'],
            typ=a['character'],
        )
        label = family[1][a['label']]
        characters_by_family[label] = character_neighbors
    families_by_casta[casta] = characters_by_family

# %%
casta_and_family = {}
for casta in families_by_casta:
    casta_and_family.setdefault(casta, [])
    max_characters = 0
    characters_by_family = families_by_casta[casta]
    for family in characters_by_family:
        num_characters = len(characters_by_family[family])
        if num_characters > max_characters:
            max_characters = num_characters
    for family in characters_by_family:
        if len(characters_by_family[family]) == max_characters:
            casta_and_family[casta].append((family, max_characters))

# %%
for casta in casta_and_family:
    print casta, ':', casta_and_family[casta]
    print '-' * 79
# Out:
# Castizo : [(u'De espa\xf1ol y mestiza, castizo', 27)]
# -------------------------------------------------------------------------------
# Mulato : [(u'De espa\xf1ol y negra produce mulato', 25)]
# -------------------------------------------------------------------------------
# Mulato  : [('De Tente en el aire y Mulata, Albarazado', 1)]
# -------------------------------------------------------------------------------
# Barcino : [('De albarazado y mulata, barcina', 7)]
# -------------------------------------------------------------------------------
# Indio bárbaro : [(u'Indios B\xe1rbaros', 9)]
# -------------------------------------------------------------------------------
# Chino cambujo : [('De indio y negra, chino cambujo', 3)]
# -------------------------------------------------------------------------------
# Mulata : [(u'De espa\xf1ol y mulata produce morisca', 1)]
# -------------------------------------------------------------------------------
# Unspecified : [(u'De espa\xf1ol y de India, produce mestizo', 6)]
# -------------------------------------------------------------------------------
# Chamizo : [('De coyote e india, chamizo', 6)]
# -------------------------------------------------------------------------------
# Chino albarazado : [('De barcino y mulata, chino albarazado', 1)]
# -------------------------------------------------------------------------------
# Lobo que es torna atrás : [(u'De lobo y de india, produce lobo que es torna atr\xe1s', 2)]
# -------------------------------------------------------------------------------
# Indio Cacique : [('Indios Caciques', 2)]
# -------------------------------------------------------------------------------
# Español : [(u'De espa\xf1ol y de India, produce mestizo', 1)]
# -------------------------------------------------------------------------------
# Indio apache : [('Indios Apaches', 11)]
# -------------------------------------------------------------------------------
# Lobo : [('De negro y de india, produce lobo', 16)]
# -------------------------------------------------------------------------------
# Indio bárbaro montarese : [(u'Indios b\xe1rbaros montarases', 5)]
# -------------------------------------------------------------------------------
# Lobo tente en el aire : [('De mulato y Mestiza, Lobo tente en el aire', 1)]
# -------------------------------------------------------------------------------
# Morisco : [(u'De espa\xf1ol y mulata produce morisca', 26)]
# -------------------------------------------------------------------------------
# Calpamulato : [('Indio con Mulata, sale Calpamulato', 3)]
# -------------------------------------------------------------------------------
# Albino : [(u'De espa\xf1ol y de morisca, produce albino', 24)]
# -------------------------------------------------------------------------------
# Grifo que es tente en el aire : [('De Indio y loba, produce un grifo que es tente en el aire', 1)]
# -------------------------------------------------------------------------------
# Español  : [(u'De castizo y espa\xf1ola, produce espa\xf1ol', 53)]
# -------------------------------------------------------------------------------
# Gibaro : [(u'De barcino e indio, g\xedbaro', 1), (u'De negro con pelo liso e india, g\xedbaro', 1), (u'De calpamulato e india, g\xedbaro', 1), (u'De g\xedbaro y loba, barcino', 1), (u'De chino y mulata, g\xedbarao', 1), (u'De genizaro y mulata, g\xedbaro', 1), (u'De g\xedbaro y mulata, tente en el aire', 1), (u'De g\xedbaro e india, chamicoyote', 1)]
# -------------------------------------------------------------------------------
# Coyote : [('De mestizo y de india, produce coyote', 14)]
# -------------------------------------------------------------------------------
# Chino : [('De lobo y negra, chino', 3)]
# -------------------------------------------------------------------------------
# Negro : [(u'De espa\xf1ol y negra produce mulato', 27)]
# -------------------------------------------------------------------------------
# Campa mulato : [('De barcino e india, campa mulato', 3)]
# -------------------------------------------------------------------------------
# Tente en el aire : [('De Tente en el aire y Mulata, Albarazado', 5)]
# -------------------------------------------------------------------------------
# Albarazado : [('De albarazado y mulata, barcina', 7)]
# -------------------------------------------------------------------------------
# No te entiendo : [('No te entiendo con india, sale china', 1), ('Cambujo con Mulata, sale No te entiendo', 1), ('No te entiendo con cambujo, tente en el aire', 1)]
# -------------------------------------------------------------------------------
# Indios Caciques : [('Indios Caciques', 1)]
# -------------------------------------------------------------------------------
# Gíbaro : [(u'De calpamulato e india, g\xedbaro', 1)]
# -------------------------------------------------------------------------------
# Indio mexicano : [('Indios Mexicanos', 2)]
# -------------------------------------------------------------------------------
# Salta atrás : [(u'De albarazado y salta atr\xe1s, tente en el aire', 1)]
# -------------------------------------------------------------------------------
# Indio Meco : [('Indios mecos', 4)]
# -------------------------------------------------------------------------------
# Cambujo : [('De Cambujo e India, Zambaigo', 4), ('De Cambujo e India, Tente en el aire', 4)]
# -------------------------------------------------------------------------------
# Indio  : [('Indios mecos', 3)]
# -------------------------------------------------------------------------------
# Sambaygo : [('Lobo con Mulata, sale Sambaygo', 1), ('Sambaygo con India, sale Cambuja', 1)]
# -------------------------------------------------------------------------------
# Mulato es torna atrás : [(u'De mulato y de mestiza, produce mulato que es torna atr\xe1s', 3)]
# -------------------------------------------------------------------------------
# Genizaro : [('De barcino y zambaiga, genizaro', 1), ('De chino e india, genizaro', 1), (u'De genizaro y mulata, g\xedbaro', 1)]
# -------------------------------------------------------------------------------
# Torna atrás : [(u'De espa\xf1ol y albina, torna atr\xe1s', 15)]
# -------------------------------------------------------------------------------
# Cachimboreta : [('De Albarazado y India, Cachimboreta', 1)]
# -------------------------------------------------------------------------------
# Lobo torna atrás : [(u'De indio y loba, lobo torna atr\xe1s', 1), (u'De Lobo torna atr\xe1s e India, Tente en el aire', 1), (u'De india y lobo torna atr\xe1s, lobo otra vez', 1), (u'De Indio y Cambuja, Lobo torna atr\xe1s', 1)]
# -------------------------------------------------------------------------------
# Indio : [(u'De espa\xf1ol y de India, produce mestizo', 29)]
# -------------------------------------------------------------------------------
# Chamicoyote : [(u'De g\xedbaro e india, chamicoyote', 1)]
# -------------------------------------------------------------------------------
# Quarteron : [('De quarteron y mestiza, coyote', 2)]
# -------------------------------------------------------------------------------
# Ahí te estás : [(u'De coyote mestizo y mulata, ah\xed te est\xe1s', 1)]
# -------------------------------------------------------------------------------
# Mestizo : [(u'De espa\xf1ol y de India, produce mestizo', 31)]
# -------------------------------------------------------------------------------
# Morio : [('De castizo y mestizo, morio', 1)]
# -------------------------------------------------------------------------------
# Negro torna atrás : [(u'De espa\xf1ol y albina, torna atr\xe1s', 2)]
# -------------------------------------------------------------------------------
# India mexicana : [('Indios Mexicanos', 1)]
# -------------------------------------------------------------------------------
# Mestindio : [('De indio y mestiza, mestindio', 1)]
# -------------------------------------------------------------------------------
# Lobo otra vez : [(u'De india y lobo torna atr\xe1s, lobo otra vez', 1)]
# -------------------------------------------------------------------------------
# Indio otomite : [('Indios otomites', 6)]
# -------------------------------------------------------------------------------
# Grifo : [('De Mulato y Albina, Grifo', 1)]
# -------------------------------------------------------------------------------
# Zambaigo : [('De Lobo e India, Zambaigo', 7)]
# -------------------------------------------------------------------------------

# %%
castas_by_family = {}
all_castas = characters_by_casta.keys()
for family in families:
    characters_by_casta = {}
    for casta in all_castas:
        character_neighbors = node_neighbor_list(
            family[0],
            castas,
            attr=a['casta'],
            value=casta,
            label=a['has'],
            typ=a['character'],
        )
        characters_by_casta[casta] = character_neighbors
    label = family[1][a['label']]
    castas_by_family[label] = characters_by_casta

# %%
def castas_by_family_top(castas_by_family, n):
    castas_by_family_top_n = castas_by_family.copy()
    for casta in all_castas:
        num_character_list = []
        for family in castas_by_family:
            characters_by_casta = castas_by_family[family]
            num_characters = len(characters_by_casta[casta])
            num_character_list.append(num_characters)
        rev_num_character_list = sorted(num_character_list, reverse=True)
        if n > len(rev_num_character_list):
            limit = list(rev_num_character_list)[-1]
        else:
            limit = list(rev_num_character_list)[n - 1]
        for family in castas_by_family:
            characters_by_casta = castas_by_family[family]
            num_characters = len(characters_by_casta[casta])
            if num_characters >= limit:
                castas_by_family_top_n[family][casta] = num_characters
            else:
                castas_by_family_top_n[family][casta] = 0
    return castas_by_family_top_n
castas_by_family_top_n = castas_by_family_top(castas_by_family, 2)

# %%
num_colors_fam = len(families)
cm_fam = get_cmap('gist_rainbow')
my_colors_fam = [cm_fam(1.*i/num_colors_fam) for i in range(num_colors_fam)]

# %%
castas_by_family_df = pd.DataFrame(castas_by_family_top_n)
ax = castas_by_family_df.plot(kind='bar', stacked=True, color=my_colors_fam, legend=False)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.45), fancybox=True, shadow=True, ncol=5, prop={'size':10})

# %% [markdown]
# ### Objects by family

# %%
objects = node_dict_by_type(castas)[a['object']]

# %%
objects_by_family = {}
all_objects = map(lambda x: x[1][a['label']], objects)
for family in families:
    characters_by_object = {}
    character_neighbors = node_neighbor_list(
        family[0],
        castas,
        label=a['has'],
        typ=a['character'],
    )
    for obj in all_objects:
        characters_by_object.setdefault(obj, [])
        for character in character_neighbors:
            object_neighbors = node_neighbor_list(
                character[0],
                castas,
                label=a['associated'],
                typ=a['object'],
            )
            object_labels = map(lambda x: x[1][a['label']], object_neighbors)
            if obj in object_labels:
                characters_by_object[obj].append(character)
    label = family[1][a['label']]
    objects_by_family[label] = characters_by_object

# %%
family_and_object = {}
for family in objects_by_family:
    family_and_object.setdefault(family, [])
    max_characters = 0
    characters_by_object = objects_by_family[family]
    for obj in characters_by_object:
        num_characters = len(characters_by_object[obj])
        if num_characters > max_characters:
            max_characters = num_characters
    for obj in characters_by_object:
        if len(characters_by_object[obj]) == max_characters:
            family_and_object[family].append((obj, max_characters))

# %%
for family in family_and_object:
    print family, ':', family_and_object[family]
    print '-' * 79
# Out:
# De mulato y coyote, chino : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# Chino con Mulata, sale Lobo : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De mulato y mestiza, mulato : [('Jewellery', 2)]
# -------------------------------------------------------------------------------
# De Chamizo e India, Albarazado : [('Shoes', 2)]
# -------------------------------------------------------------------------------
# Mulato con Español sale Quarteron : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De Torna atrás e india, loba : [('Food Items (no specified destination)', 1), ('Weapon (unidentified)', 1)]
# -------------------------------------------------------------------------------
# De Castizo y Mestiza, Chamizo : [('Tobacco/Snuffbox', 2)]
# -------------------------------------------------------------------------------
# Quarteron con Español, sale Torna atrás : [('Instrument', 1)]
# -------------------------------------------------------------------------------
# De Chino cambujo y de India, Loba : [('Toy', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De español y de India, produce mestizo : [('Jewellery', 30)]
# -------------------------------------------------------------------------------
# De Chino y Albina, Torna atrás : [('Toy', 1), ('Holding an animal', 1), ('Black beauty mark', 1)]
# -------------------------------------------------------------------------------
# De zambaigo y mulata, barcino : [('Food Items (no specified destination)', 1), ('Holding food item for sale', 1), ('Material/Textile goods', 1)]
# -------------------------------------------------------------------------------
# Español y Española, Español : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De castizo y mestizo, morio : [('Food Items (no specified destination)', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# No te entiendo con india, sale china : [('Food Items (no specified destination)', 1)]
# -------------------------------------------------------------------------------
# Sambaygo con India, sale Cambuja : [('Food Items (no specified destination)', 1), ('Holding an animal', 1), ('Shoes', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De india y coyote, produce zambaigo. : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# Indios Caciques : [('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De india y lobo, tente en el aire : [('Holding an animal', 1)]
# -------------------------------------------------------------------------------
# Lobo con Mulata, sale Sambaygo : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De barcino e indio, gíbaro : [('Food Items (no specified destination)', 2)]
# -------------------------------------------------------------------------------
# De mulato y de mestiza, produce mulato que es torna atrás : [('Jewellery', 5)]
# -------------------------------------------------------------------------------
# De quarteron y mestiza, coyote : [('Sword/Knife', 3)]
# -------------------------------------------------------------------------------
# De negro con pelo liso e india, gíbaro : [('Food Items (no specified destination)', 1), ('Instrument', 1)]
# -------------------------------------------------------------------------------
# De calpamulato e india, gíbaro : [('Holding an animal', 2), ('Jewellery', 2)]
# -------------------------------------------------------------------------------
# De indio y mestiza, mestindio : [('Food Items (no specified destination)', 1)]
# -------------------------------------------------------------------------------
# De coyote e india, chamizo : [('Jewellery', 4)]
# -------------------------------------------------------------------------------
# De Cambujo e India, Chamizo : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De Zambaigo e India, Albarazado : [('Holding food item for sale', 4)]
# -------------------------------------------------------------------------------
# De español y castiza, castiza : [('Holding food item for sale', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# Albarazado con Mulata, Sale Tente en el aire : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# Indios : [('Bow and arrow', 1)]
# -------------------------------------------------------------------------------
# De gíbaro y loba, barcino : [('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De Cambujo e India, Zambaigo : [('Food Items (no specified destination)', 3), ('Sewing equipment', 3)]
# -------------------------------------------------------------------------------
# De Cambujo e India, Tente en el aire : [('Food Items (no specified destination)', 3), ('Shoes', 3)]
# -------------------------------------------------------------------------------
# De Albarazado e India, Barcino : [('Food Items (no specified destination)', 3)]
# -------------------------------------------------------------------------------
# De indio y loba, lobo torna atrás : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De Chamizo e India, Cambujo : [('Food Items (no specified destination)', 2)]
# -------------------------------------------------------------------------------
# De indio y negra, chino cambujo : [('Jewellery', 2)]
# -------------------------------------------------------------------------------
# De español y mestiza, castizo : [('Jewellery', 26)]
# -------------------------------------------------------------------------------
# Indios Apaches : [('Bow and arrow', 5)]
# -------------------------------------------------------------------------------
# Calpamulato con Mulato, sale Albarazado : [('Sewing equipment', 2)]
# -------------------------------------------------------------------------------
# De español y albina, torna atrás : [('Jewellery', 14)]
# -------------------------------------------------------------------------------
# De Coyote e India, Cambujo : [('Food Items (no specified destination)', 4)]
# -------------------------------------------------------------------------------
# De chino y mulata, gíbarao : [('Kitchen utensils', 1)]
# -------------------------------------------------------------------------------
# De Indio y loba, produce un grifo que es tente en el aire : [('Jewellery', 1), ('Black beauty mark', 1)]
# -------------------------------------------------------------------------------
# Indios Mexicanos : [('Holding food item for sale', 2)]
# -------------------------------------------------------------------------------
# De gíbaro y mulata, tente en el aire : [('Instrument', 1)]
# -------------------------------------------------------------------------------
# De barcino y zambaiga, genizaro : [('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De lobo y mestiza, cambujo : [('Kitchen utensils', 1), ('Weapon (unidentified)', 1)]
# -------------------------------------------------------------------------------
# De coyote y morisca, albarazado : [('Jewellery', 2)]
# -------------------------------------------------------------------------------
# De Chino y Mulata, Cambujo : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De Tente en el aire y Mulata, Albarazado : [('Holding food item for sale', 8)]
# -------------------------------------------------------------------------------
# De torna atrás y albarazado, tente en el aire : [('Holding food item for sale', 2)]
# -------------------------------------------------------------------------------
# De castizo y española, produce español : [('Jewellery', 26)]
# -------------------------------------------------------------------------------
# Cambujo con Mulata, sale No te entiendo : [('Weapon (unidentified)', 1)]
# -------------------------------------------------------------------------------
# De mestizo y de india, produce coyote : [('Jewellery', 10)]
# -------------------------------------------------------------------------------
# De chino e india, genizaro : [('Sewing equipment', 3)]
# -------------------------------------------------------------------------------
# De barcino e india, campa mulato : [('Holding food item for sale', 2)]
# -------------------------------------------------------------------------------
# De zambaigo y mulata, calpamulata : [('Tobacco/Snuffbox', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De barcino y mulata, tornatras de pelo lizo : [('Jewellery', 2)]
# -------------------------------------------------------------------------------
# De coyote mestizo y mulata, ahí te estás : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De Barcina e Indio, China : [('Sewing equipment', 2)]
# -------------------------------------------------------------------------------
# De Español y Torna atrás, Tente en el aire : [('Food Items (no specified destination)', 2), ('Material/Textile goods', 2), ('Jewellery', 2)]
# -------------------------------------------------------------------------------
# De lobo y negra, chino : [('Material/Textile goods', 3)]
# -------------------------------------------------------------------------------
# De español y chamiza, barcino : [('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De Español y Albina, Negro : [('Fan', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De cambujo y mulata, zambaigo : [('Food Items (no specified destination)', 1), ('Shoes', 1)]
# -------------------------------------------------------------------------------
# De Barcino y Loba, Coyote : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De calpamulato y coyota, barcina : [('Instrument', 1), ('Holding an animal', 1), ('Kitchen utensils', 1)]
# -------------------------------------------------------------------------------
# De Albarazado y India, Cachimboreta : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De india y lobo torna atrás, lobo otra vez : [('Jewellery', 2)]
# -------------------------------------------------------------------------------
# Indio con Mulata, sale Calpamulato : [('Cards', 3)]
# -------------------------------------------------------------------------------
# Indios otomites : [('Holding an animal', 2)]
# -------------------------------------------------------------------------------
# De chino cambujo y mulata, albarazado : [('Jewellery', 2)]
# -------------------------------------------------------------------------------
# De mestizo e india, lobo : [('Shoes', 1)]
# -------------------------------------------------------------------------------
# De cambujo y mulata, albarazado : [('Shoes', 2)]
# -------------------------------------------------------------------------------
# De barcino y mulata, chino albarazado : [('Food Items (no specified destination)', 2)]
# -------------------------------------------------------------------------------
# De Lobo torna atrás e India, Tente en el aire : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De lobo e india, chino cambujo : [('Food Items (no specified destination)', 1), ('Shoes', 1)]
# -------------------------------------------------------------------------------
# Indios mecos : [('Bow and arrow', 6)]
# -------------------------------------------------------------------------------
# De negro y de india, produce lobo : [('Food Items (no specified destination)', 11)]
# -------------------------------------------------------------------------------
# De español y mulata produce morisca : [('Jewellery', 23)]
# -------------------------------------------------------------------------------
# Negro con India, sale Chino : [('Whip', 2)]
# -------------------------------------------------------------------------------
# De Lobo y de India, Albarazado : [('Holding food item for sale', 2)]
# -------------------------------------------------------------------------------
# De Indio y Albarazada, Chamizo : [('Holding food item for sale', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De chino e india, cambujo : [('Food Items (no specified destination)', 4)]
# -------------------------------------------------------------------------------
# De Chamizo y Cambuja, Chino : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De Lobo e India, Zambaigo : [('Jewellery', 3)]
# -------------------------------------------------------------------------------
# De mulato e india, chino : [('Holding food item for sale', 2)]
# -------------------------------------------------------------------------------
# Indios bárbaros montarases : [('Bow and arrow', 1)]
# -------------------------------------------------------------------------------
# De albarazado y mulata, barcina : [('Jewellery', 4)]
# -------------------------------------------------------------------------------
# De Barcino y Cambuja, Calpamulato : [('Food Items (no specified destination)', 1), ('Holding food item for sale', 1)]
# -------------------------------------------------------------------------------
# De Albarazado y Mestiza, Barcino : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De Torna atrás y Grifo, Chino : [('Holding an animal', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De español y negra produce mulato : [('Kitchen utensils', 14)]
# -------------------------------------------------------------------------------
# Cambujo con india, albarazado : [('Sewing equipment', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# Tente en el aire con India, sale -Unknown- : [('Food Items (no specified destination)', 2)]
# -------------------------------------------------------------------------------
# De barcino y mulata, china : [('Instrument', 1)]
# -------------------------------------------------------------------------------
# De mulato y Mestiza, Lobo tente en el aire : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De quarteron y mestiza, mulato : [('Food Items (no specified destination)', 1)]
# -------------------------------------------------------------------------------
# De español y de morisca, produce albino : [('Jewellery', 20)]
# -------------------------------------------------------------------------------
# De mulato y mestiza, quarteron : [('Shoes', 1), ('Jewellery', 1), ('Black beauty mark', 1)]
# -------------------------------------------------------------------------------
# De lobo y de india, produce lobo que es torna atrás : [('Jewellery', 3)]
# -------------------------------------------------------------------------------
# De barcino y mulata, coyote : [('Instrument', 1)]
# -------------------------------------------------------------------------------
# De genizaro y mulata, gíbaro : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De Mulato y Albina, Grifo : [('Shoes', 1), ('Jewellery', 1)]
# -------------------------------------------------------------------------------
# No te entiendo con cambujo, tente en el aire : [('Food Items (no specified destination)', 1), ('Shoes', 1)]
# -------------------------------------------------------------------------------
# Indios Bárbaros : [('Bow and arrow', 5)]
# -------------------------------------------------------------------------------
# De gíbaro e india, chamicoyote : [('Toy', 0), ('Checkers', 0), ('Food Items (no specified destination)', 0), ('Instrument', 0), ('Brazier', 0), ('Sewing equipment', 0), ('Pottery/ceramics', 0), ('Holding an animal', 0), ('Tobacco/Snuffbox', 0), ('Holding food item for sale', 0), ('Fan', 0), ('Kitchen utensils', 0), ('Weapon (unidentified)', 0), ('Bow and arrow', 0), ('Material/Textile goods', 0), ('Gun', 0), ('Writing Utensils/Book', 0), ('Cards', 0), ('Wig', 0), ('Sword/Knife', 0), ('Shoes', 0), ('Jewellery', 0), ('Black beauty mark', 0), ('Whip', 0)]
# -------------------------------------------------------------------------------
# De lobo e india, cambuja : [('Food Items (no specified destination)', 5)]
# -------------------------------------------------------------------------------
# De Indio y Cambuja, Lobo torna atrás : [('Whip', 1)]
# -------------------------------------------------------------------------------
# De albarazado y salta atrás, tente en el aire : [('Jewellery', 1)]
# -------------------------------------------------------------------------------
# De India y Cambujo, Torna atrás : [('Instrument', 1), ('Holding an animal', 1)]
# -------------------------------------------------------------------------------
# De indio y Barcina, Zambayga : [('Food Items (no specified destination)', 4)]
# -------------------------------------------------------------------------------
# De mestiza y mulato, calpamulato : [('Jewellery', 2)]
# -------------------------------------------------------------------------------

# %%
all_families = map(lambda x: x[1][a['label']], node_dict_by_type(castas)[a['family']])

# %%
family_by_objects = {}
all_objects = map(lambda x: x[1][a['label']], objects)
for obj in all_objects:
    characters_by_family = {}
    for family in families:
        label = family[1][a['label']]
        characters_by_family.setdefault(label, [])
        character_neighbors = node_neighbor_list(
            family[0],
            castas,
            label=a['has'],
            typ=a['character'],
        )
        for character in character_neighbors:
            object_neighbors = node_neighbor_list(
                character[0],
                castas,
                label=a['associated'],
                typ=a['object'],
            )
            object_labels = map(lambda x: x[1][a['label']], object_neighbors)
            if obj in object_labels:
                characters_by_family[label].append(character)
    family_by_objects[obj] = characters_by_family

# %%
def families_by_object_top(families_by_object, n):
    families_by_object_top_n = families_by_object.copy()
    for family in all_families:
        num_character_list = []
        for obj in families_by_object:
            characters_by_family = families_by_object[obj]
            num_characters = len(characters_by_family[family])
            num_character_list.append(num_characters)
        rev_num_character_list = sorted(num_character_list, reverse=True)
        if n > len(rev_num_character_list):
            limit = list(rev_num_character_list)[-1]
        else:
            limit = list(rev_num_character_list)[n - 1]
        for obj in families_by_object:
            characters_by_family = families_by_object[obj]
            num_characters = len(characters_by_family[family])
            if num_characters >= limit:
                families_by_object_top_n[obj][family] = num_characters
            else:
                families_by_object_top_n[obj][family] = 0
    return families_by_object_top_n
families_by_object_top_n = families_by_object_top(family_by_objects, 2)

# %%
num_colors_obj = len(objects)
cm_obj = get_cmap('gist_rainbow')
my_colors_obj = [cm_obj(1.*i/num_colors_obj) for i in range(num_colors_obj)]

# %%
family_by_objects_df = pd.DataFrame(families_by_object_top_n)
ax = family_by_objects_df.plot(kind='bar', stacked=True, color=my_colors_obj, legend=False)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -1.7), fancybox=True, shadow=True, ncol=6, prop={'size':10})

# %% [markdown]
# ## Violence

# %%
violent_actions = [a['fighting'], a['non-fighting'], a['crying']]

# %% [markdown]
# ### Characters by receiving action

# %%
characters_by_receiving_action = {}
actions = map(lambda x: x[0], node_dict_by_type(castas)[a['action']])
for action in actions:
    character_neighbors = node_neighbor_list(
        action,
        castas,
        label=a['receiving'],
        typ=a['character'],
    )
    label = castas.node[action][a['label']]
    characters_by_receiving_action[label] = character_neighbors
freq_characters_by_receiving_action = freq_dict(characters_by_receiving_action)

# %% [markdown]
# ### Characters receiving violence

# %%
characters_receiving_fighting = characters_by_receiving_action[a['fighting']]

# %%
characters_receiving_non_fighting = characters_by_receiving_action[a['non-fighting']]

# %%
characters_receiving_crying = characters_by_receiving_action[a['crying']]

# %%
characters_receiving_violence = characters_receiving_fighting + characters_receiving_non_fighting + characters_receiving_crying

# %% [markdown]
# ### Characters by doing action

# %%
characters_by_doing_action = {}
for character in characters:
    action_neighbors = node_neighbor_list(
        character[0],
        castas,
        label=a['doing'],
        typ=a['action'],
    )
    for action in action_neighbors:
        label = action[1][a['label']]
        characters_by_doing_action.setdefault(label, [])
        characters_by_doing_action[label].append(character)
freq_characters_by_doing_action = freq_dict(characters_by_doing_action)
all_actions = map(lambda x: x[1][a['label']], node_dict_by_type(castas)[a['action']])
freq_spaniards_by_doing_action = equalize_dict(all_actions, freq_characters_by_doing_action)

# %% [markdown]
# ### Characters doing violence

# %%
characters_doing_fighting = characters_by_doing_action[a['fighting']]

# %%
characters_doing_non_fighting = characters_by_doing_action[a['non-fighting']]

# %%
characters_doing_crying = characters_by_doing_action[a['crying']]

# %%
characters_doing_violence = characters_doing_fighting + characters_doing_non_fighting + characters_doing_crying

# %% [markdown]
# ### Violent characters

# %%
characters_fighting = characters_receiving_fighting + characters_doing_fighting

# %%
characters_non_fighting = characters_receiving_non_fighting + characters_doing_non_fighting

# %%
characters_crying = characters_receiving_crying + characters_doing_crying

# %%
violent_characters = characters_fighting + characters_non_fighting + characters_crying

# %% [markdown]
# ### Paintings that demonstrate violent depictions

# %%
violent_character_ids = map(lambda x: x[0], violent_characters)

# %%
paintings_by_violence = {'violence': [], 'non-violence': []}
for painting in paintings:
    character_neighbors = node_neighbor_list(
        painting[0],
        castas,
        label=a['depicts'],
        typ=a['character'],
    )
    for character in character_neighbors:
        if character[0] in violent_character_ids:
            paintings_by_violence['violence'].append(painting)
        else:
            paintings_by_violence['non-violence'].append(painting)
freq_paintings_by_violence = freq_dict(paintings_by_violence)

# %%
figure(1, figsize=(6,6))
paintings_by_violence_sr = pd.Series(freq_paintings_by_violence)
plt.pie(paintings_by_violence_sr, labels=paintings_by_violence_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=['g','y'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1496c150>,
#   <matplotlib.patches.Wedge at 0x14cb72d0>],
#  [<matplotlib.text.Text at 0x1496cf90>, <matplotlib.text.Text at 0x14cb79d0>],
#  [<matplotlib.text.Text at 0x14cb7210>, <matplotlib.text.Text at 0x14cb7c10>])

# %% [markdown]
# ### Paintings that demonstrate violent depictions by violent actions

# %%
characters_fighting_ids = map(lambda x: x[0], characters_fighting)
characters_non_fighting_ids = map(lambda x: x[0], characters_non_fighting)
characters_crying_ids = map(lambda x: x[0], characters_crying)

paintings_by_violent_action = {}
for action in violent_actions:
    paintings_by_violent_action.setdefault(action, [])

for painting in paintings:
    character_neighbors = node_neighbor_list(
        painting[0],
        castas,
        label=a['depicts'],
        typ=a['character'],
    )
    for character in character_neighbors:
        if character[0] in characters_fighting_ids:
            paintings_by_violent_action[violent_actions[0]].append(painting)
        if character[0] in characters_non_fighting_ids:
            paintings_by_violent_action[violent_actions[1]].append(painting)
        if character[0] in characters_crying_ids:
            paintings_by_violent_action[violent_actions[2]].append(painting)

freq_paintings_by_violent_action = freq_dict(paintings_by_violent_action)

# %%
figure(1, figsize=(6,6))
paintings_by_violent_action_sr = pd.Series(freq_paintings_by_violent_action)
plt.pie(paintings_by_violent_action_sr, labels=paintings_by_violent_action_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=['c', 'g', 'r'])
# Out:
# ([<matplotlib.patches.Wedge at 0x15b9e850>,
#   <matplotlib.patches.Wedge at 0x15ba1390>,
#   <matplotlib.patches.Wedge at 0x15ba1d50>],
#  [<matplotlib.text.Text at 0x15ba1090>,
#   <matplotlib.text.Text at 0x15ba1a90>,
#   <matplotlib.text.Text at 0x15ba5490>],
#  [<matplotlib.text.Text at 0x15ba12d0>,
#   <matplotlib.text.Text at 0x15ba1cd0>,
#   <matplotlib.text.Text at 0x15ba56d0>])

# %% [markdown]
# ### Violent paintings with Spanish characters

# %%
violent_spanish_paintings_set = set()
for action in violent_actions:
    spaniards = spaniards_by_doing_action[action] + spaniards_by_receiving_action[action]
    spaniards_ids = map(lambda x: x[0], spaniards)
    for painting in paintings:
        character_neighbors = node_neighbor_list(
            painting[0],
            castas,
            label=a['depicts'],
            typ=a['character'],
        )
        character_neighbors_ids = map(lambda x: x[0], character_neighbors)
        for character_id in character_neighbors_ids:
            if character_id in spaniards_ids:
                violent_spanish_paintings_set.add(painting[0])
                break
violent_spanish_paintings = [(ide, castas.node[ide]) for ide in violent_spanish_paintings_set]

# %%
violent_spanish_paintings
# Out:
# [('15168',
#   {'(Painting) CreationYearEnd': u'1787',
#    '(Painting) CreationYearStart': u'1787',
#    '(Painting) CurrentPlaceId': u'366',
#    '(Painting) CurrentPlaceTitle': u'Mexico',
#    '(Painting) Incription': u'',
#    '(Painting) Name': u'7. De espa\xf1ol y albina, torna atr\xe1s; 8. De torna atr\xe1s e india, loba',
#    '(Painting) Notes': u'serie? La pintura se encuentra en blanco y negro. El dato de la localizaci\xf3n actual se desconoce, la fuente s\xf3lo menciona -Colecci\xf3n particular.-',
#    '(Painting) OriginalPlaceId': u'',
#    '(Painting) OriginalPlaceTitle': u'',
#    '(Painting) References': u'La pintura de castas: representaciones raciales en el M\xe9xico del siglo XVIII Katzew, Ilona   Katzew, Ilona. La pintura de castas: representaciones raciales en el M\xe9xico del siglo XVIII. Madrid: Turner, 2004.  Montreal',
#    '(Painting) Size': u'35.5 x 47.7 cm',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'7. De espa\xf1ol y albina, torna atr\xe1s; 8. De torna atr\xe1s e india, loba'}),
#  ('15143',
#   {'(Painting) CreationYearEnd': u'1785',
#    '(Painting) CreationYearStart': u'1785',
#    '(Painting) CurrentPlaceId': u'1486',
#    '(Painting) CurrentPlaceTitle': u'Denver Art Museum (Denver, United States)',
#    '(Painting) Incription': u'',
#    '(Painting) Name': u'5. De mulato y espa\xf1ola, morisco.',
#    '(Painting) Notes': u'serie?',
#    '(Painting) OriginalPlaceId': u'',
#    '(Painting) OriginalPlaceTitle': u'',
#    '(Painting) References': u'La pintura de castas: representaciones raciales en el M\xe9xico del siglo XVIII Katzew, Ilona   Katzew, Ilona. La pintura de castas: representaciones raciales en el M\xe9xico del siglo XVIII. Madrid: Turner, 2004.  Montreal',
#    '(Painting) Size': u'54 X 40.5 cm.',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'5. De mulato y espa\xf1ola, morisco.'}),
#  ('15369',
#   {'(Painting) CreationYearEnd': u'1799',
#    '(Painting) CreationYearStart': u'1766',
#    '(Painting) CurrentPlaceId': u'1535',
#    '(Painting) CurrentPlaceTitle': u'Instituto de Cultura de Puertorrique\xf1a (San Juan, Puerto Rico)',
#    '(Painting) Incription': u'3. De Espa\xf1ol y Negra, nace Mulata',
#    '(Painting) Name': u'3. De espa\xf1ol y negra, nace mulata',
#    '(Painting) Notes': u'Ulimo tercio del siglo XVIII -Concepci\xf3n Garcia S\xe1iz proporciona importantes informaciones acerca de esta serie de pinturas de castas; \xe9stas fueron localizadas originalmente por I. Moreno, en Sevilla y m\xe1s tarde pasaron al Instituto de Cultura Puertorrique\xf1a, para formar parte de su acervo. Las escenas de violencia en las pinturas de castas, se concentran mayormente en algunas que el arzobispo Francisco Antonio Lorenzana definiera como -no limpias-, en sus Avisos para la acertada conducta de un p\xe1rroco en Am\xe9rica (1769). El -espa\xf1ol-, de baja condici\xf3n en esta escena, recibe los furiosos golpes que con un molinillo para batir chocolate le propina la airada -negra- en la frente dentro del ambiente dom\xe9stico de la cocina, mientras la peque\xf1a -mulata-, aterrada, intenta separar a la pareja. Si bien el grupo familiar responde sin variantes al modelo que utilizara Andr\xe9s de Islas en 1774, el tratamiento de las telas en la indumentaria feminina y los detalles en relaci\xf3n con los utensilios de cocina muestran gran libertad, ya que en ninguna de las pinturas de esta casta en otras series se repiten. Incluso, en este ejemplo, el terceto se desplaza a la izquierda para mostrar m\xe1s detalles del fog\xf3n y la alacena, aun cuando aqu\xed se han eliminado los frutos de la tierra, que en la pintura correspondiente de Andr\xe9s de Islas tienen un lugar de preferencia. EEIG- (Nueva Espa\xf1a 2)',
#    '(Painting) OriginalPlaceId': u'',
#    '(Painting) OriginalPlaceTitle': u'M\xe9xico-Mexico (Mexico)',
#    '(Painting) References': u'Mexico en el mundo de las colecciones de arte. Nueva Espa\xf1a 2    Mexico en el mundo de las colecciones de arte. Nueva Espa\xf1a 2. Mexico: Secretar\xeda de Relaciones Exteriores, 1994.     Biblioteca Nacional Mexico',
#    '(Painting) Size': u'34 x 46 cm',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'3. De espa\xf1ol y negra, nace mulata'}),
#  ('15155',
#   {'(Painting) CreationYearEnd': u'1800',
#    '(Painting) CreationYearStart': u'1775',
#    '(Painting) CurrentPlaceId': u'1485',
#    '(Painting) CurrentPlaceTitle': u'Museo de Am\xe9rica (Madrid, Spain)',
#    '(Painting) Incription': u'4 de Espa\xf1ol y Negra Mulata',
#    '(Painting) Name': u'4. De espa\xf1ol y negra, mulata',
#    '(Painting) Notes': u'Serie de 16 pinturas: ID 34,35,74, 2459-2471',
#    '(Painting) OriginalPlaceId': u'1180',
#    '(Painting) OriginalPlaceTitle': u'Veracruz (Mexico)',
#    '(Painting) References': u'Catalogo del Museo de Am\xe9rica Garc\xeda Saiz, Concepci\xf3n (Dir.)   Museo de Am\xe9rica. 2009. Ministerio de Cultura. 11 Mayo. 2009  unable to locate - La pintura colonial en el Museo de Am\xe9rica (I): La escuela mexicana. Madrid: Ministerio de Cultura, 1980. Garc\xeda Saiz, Mar\xeda Concepci\xf3n   Montreal',
#    '(Painting) Size': u'36 x 48 cm',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'4. De espa\xf1ol y negra, mulata'}),
#  ('15316',
#   {'(Painting) CreationYearEnd': u'1715',
#    '(Painting) CreationYearStart': u'1715',
#    '(Painting) CurrentPlaceId': u'648',
#    '(Painting) CurrentPlaceTitle': u'Breamore House (Hampshire, United Kingdom)',
#    '(Painting) Incription': u'',
#    '(Painting) Name': u'De castizo y espa\xf1ola, produce espa\xf1ol',
#    '(Painting) Notes': u'ca. 1715 atribuido a Juan Rodr\xedguez Ju\xe1rez.  \xa8Casta Painting: Images of Race in Eighteenth-Century Mexico\xa8 By Ilona Katzew. p 13',
#    '(Painting) OriginalPlaceId': u'651',
#    '(Painting) OriginalPlaceTitle': u'M\xe9xico-Mexico (Mexico)',
#    '(Painting) References': u'Painting a New World, Mexican Art and Life, 1521-1821 Pierce, Donna, R. Ruiz Gomar, and C. Bargellini, ed.   Pierce, Donna, R. Ruiz Gomar, and C. Bargellini, ed. Painting a New World. Mexican Art and Life, 1521-1821. Intr. Jonathan Brown. Denver; Austin: Denver Art Museum; Texas UP, 2004.                 UWO \u2013 ND253.P54',
#    '(Painting) Size': u'80.7 x 105.4 cm',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'De castizo y espa\xf1ola, produce espa\xf1ol'}),
#  ('15219',
#   {'(Painting) CreationYearEnd': u'1774',
#    '(Painting) CreationYearStart': u'1774',
#    '(Painting) CurrentPlaceId': u'1485',
#    '(Painting) CurrentPlaceTitle': u'Museo de Am\xe9rica (Madrid, Spain)',
#    '(Painting) Incription': u'La pintura presenta en la parte superior un listado de 14 frutas. Y los personajes aparecen peleando.',
#    '(Painting) Name': u'No. 4. De espa\xf1ol y negra, nace mulata',
#    '(Painting) Notes': u'Virreinato de Nueva Espa\xf1a.',
#    '(Painting) OriginalPlaceId': u'366',
#    '(Painting) OriginalPlaceTitle': u'Mexico',
#    '(Painting) References': u'Catalogo del Museo de Am\xe9rica Garc\xeda Saiz, Concepci\xf3n (Dir.)   Museo de Am\xe9rica. 2009. Ministerio de Cultura. 11 Mayo. 2009  unable to locate - La pintura de castas: representaciones raciales en el M\xe9xico del siglo XVIII Katzew, Ilona   Katzew, Ilona. La pintura de castas: representaciones raciales en el M\xe9xico del siglo XVIII. Madrid: Turner, 2004.  Montreal',
#    '(Painting) Size': u'75 X 54 cm',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'No. 4. De espa\xf1ol y negra, nace mulata'}),
#  ('17261',
#   {'(Painting) CreationYearEnd': u'1799',
#    '(Painting) CreationYearStart': u'1750',
#    '(Painting) CurrentPlaceId': u'',
#    '(Painting) CurrentPlaceTitle': u'Private Collection, Mexico',
#    '(Painting) Incription': u'7. De Espa\xf1ol, y Negra, nace Mulato',
#    '(Painting) Name': u'7. De Espa\xf1ol y Negra, nace Mulato',
#    '(Painting) Notes': u'',
#    '(Painting) OriginalPlaceId': u'',
#    '(Painting) OriginalPlaceTitle': u'M\xe9xico-Mexico (Mexico)',
#    '(Painting) References': u'Garc\xeda Sa\xedz, Mar\xeda Concepci\xf3n. Las castas mexicanas: un g\xe9nero pict\xf3rico americano. Olivetti: 1989. pp. 184-7',
#    '(Painting) Size': u'43 x 56 cm',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'7. De Espa\xf1ol y Negra, nace Mulato'}),
#  ('17152',
#   {'(Painting) CreationYearEnd': u'1800',
#    '(Painting) CreationYearStart': u'1775',
#    '(Painting) CurrentPlaceId': u'',
#    '(Painting) CurrentPlaceTitle': u'Museo Nacional, M\xe9xico',
#    '(Painting) Incription': u'N. 4. De Espa\xf1ol y Negra nace Mulata',
#    '(Painting) Name': u'N. 4. De Espa\xf1ol y Negra nace Mulata',
#    '(Painting) Notes': u'',
#    '(Painting) OriginalPlaceId': u'',
#    '(Painting) OriginalPlaceTitle': u'M\xe9xico-Mexico (Mexico)',
#    '(Painting) References': u'Garc\xeda Sa\xedz, Mar\xeda Concepci\xf3n. Las castas mexicanas: un g\xe9nero pict\xf3rico americano. Olivetti: 1989. pp. 152-3',
#    '(Painting) Size': u'33 x 43 cm',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'N. 4. De Espa\xf1ol y Negra nace Mulata'}),
#  ('15268',
#   {'(Painting) CreationYearEnd': u'1790',
#    '(Painting) CreationYearStart': u'1785',
#    '(Painting) CurrentPlaceId': u'366',
#    '(Painting) CurrentPlaceTitle': u'Mexico',
#    '(Painting) Incription': u'',
#    '(Painting) Name': u'De espa\xf1ol y negra, nace mulata',
#    '(Painting) Notes': u'',
#    '(Painting) OriginalPlaceId': u'',
#    '(Painting) OriginalPlaceTitle': u'',
#    '(Painting) References': u'La pintura de castas: representaciones raciales en el M\xe9xico del siglo XVIII Katzew, Ilona   Katzew, Ilona. La pintura de castas: representaciones raciales en el M\xe9xico del siglo XVIII. Madrid: Turner, 2004.  Montreal',
#    '(Painting) Size': u'62.6 X 83.2 cm',
#    '[Schema] Type': u'Painting',
#    '[Schema] Type Id': u'811',
#    'label': u'De espa\xf1ol y negra, nace mulata'})]

# %% [markdown]
# ### Characters receiving violence by casta

# %%
characters_receiving_violence_by_casta = {}
for action in actions:
    if castas.node[action][a['label']] in violent_actions:
        character_neighbors = node_neighbor_list(
            action,
            castas,
            label=a['receiving'],
            typ=a['character'],
        )
        for character in character_neighbors:
            label = character[1][a['casta']]
            characters_receiving_violence_by_casta.setdefault(label, [])
            characters_receiving_violence_by_casta[label].append(character)
freq_characters_receiving_violence_by_casta = freq_dict(characters_receiving_violence_by_casta)

# %%
figure(1, figsize=(10,10))
characters_receiving_violence_by_casta_sr = pd.Series(freq_characters_receiving_violence_by_casta)
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'w']
plt.pie(characters_receiving_violence_by_casta_sr, labels=characters_receiving_violence_by_casta_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x15bbe250>,
#   <matplotlib.patches.Wedge at 0x15bbed50>,
#   <matplotlib.patches.Wedge at 0x15db6750>,
#   <matplotlib.patches.Wedge at 0x15db9150>,
#   <matplotlib.patches.Wedge at 0x15db9b10>,
#   <matplotlib.patches.Wedge at 0x15dbc510>,
#   <matplotlib.patches.Wedge at 0x15dbced0>,
#   <matplotlib.patches.Wedge at 0x15dbf8d0>,
#   <matplotlib.patches.Wedge at 0x15dc22d0>,
#   <matplotlib.patches.Wedge at 0x15dc2c90>,
#   <matplotlib.patches.Wedge at 0x15dc6690>],
#  [<matplotlib.text.Text at 0x15bbea50>,
#   <matplotlib.text.Text at 0x15db6490>,
#   <matplotlib.text.Text at 0x15db6e50>,
#   <matplotlib.text.Text at 0x15db9850>,
#   <matplotlib.text.Text at 0x15dbc250>,
#   <matplotlib.text.Text at 0x15dbcc10>,
#   <matplotlib.text.Text at 0x15dbf610>,
#   <matplotlib.text.Text at 0x15dbffd0>,
#   <matplotlib.text.Text at 0x15dc29d0>,
#   <matplotlib.text.Text at 0x15dc63d0>,
#   <matplotlib.text.Text at 0x15dc6d90>],
#  [<matplotlib.text.Text at 0x15bbec90>,
#   <matplotlib.text.Text at 0x15db66d0>,
#   <matplotlib.text.Text at 0x15db6f10>,
#   <matplotlib.text.Text at 0x15db9a90>,
#   <matplotlib.text.Text at 0x15dbc490>,
#   <matplotlib.text.Text at 0x15dbce50>,
#   <matplotlib.text.Text at 0x15dbf850>,
#   <matplotlib.text.Text at 0x15dc2250>,
#   <matplotlib.text.Text at 0x15dc2c10>,
#   <matplotlib.text.Text at 0x15dc6610>,
#   <matplotlib.text.Text at 0x15dc6ed0>])

# %% [markdown]
# ### Male characters receiving violence by casta

# %%
male_characters_receiving_violence_by_casta = {}
for action in actions:
    if castas.node[action][a['label']] in violent_actions:
        character_neighbors = node_neighbor_list(
            action,
            castas,
            label=a['receiving'],
            typ=a['character'],
            attr=a['male'],
            value=a['true']
        )
        for character in character_neighbors:
            label = character[1][a['casta']]
            male_characters_receiving_violence_by_casta.setdefault(label, [])
            male_characters_receiving_violence_by_casta[label].append(character)
freq_male_characters_receiving_violence_by_casta = freq_dict(male_characters_receiving_violence_by_casta)

# %%
figure(1, figsize=(6,6))
male_characters_receiving_violence_by_casta_sr = pd.Series(freq_male_characters_receiving_violence_by_casta)
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'w', 'g']
plt.pie(male_characters_receiving_violence_by_casta_sr, labels=male_characters_receiving_violence_by_casta_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x15ddfad0>,
#   <matplotlib.patches.Wedge at 0x15de2610>,
#   <matplotlib.patches.Wedge at 0x15de2fd0>,
#   <matplotlib.patches.Wedge at 0x15de69d0>,
#   <matplotlib.patches.Wedge at 0x15de93d0>,
#   <matplotlib.patches.Wedge at 0x15de9d90>,
#   <matplotlib.patches.Wedge at 0x15deb790>,
#   <matplotlib.patches.Wedge at 0x15def190>],
#  [<matplotlib.text.Text at 0x15de2310>,
#   <matplotlib.text.Text at 0x15de2d10>,
#   <matplotlib.text.Text at 0x15de6710>,
#   <matplotlib.text.Text at 0x15de9110>,
#   <matplotlib.text.Text at 0x15de9ad0>,
#   <matplotlib.text.Text at 0x15deb4d0>,
#   <matplotlib.text.Text at 0x15debe90>,
#   <matplotlib.text.Text at 0x15def890>],
#  [<matplotlib.text.Text at 0x15de2550>,
#   <matplotlib.text.Text at 0x15de2f50>,
#   <matplotlib.text.Text at 0x15de6950>,
#   <matplotlib.text.Text at 0x15de9350>,
#   <matplotlib.text.Text at 0x15de9d10>,
#   <matplotlib.text.Text at 0x15deb710>,
#   <matplotlib.text.Text at 0x15debf50>,
#   <matplotlib.text.Text at 0x15defad0>])

# %% [markdown]
# ### Female characters receiving violence by casta

# %%
female_characters_receiving_violence_by_casta = {}
for action in actions:
    if castas.node[action][a['label']] in violent_actions:
        character_neighbors = node_neighbor_list(
            action,
            castas,
            label=a['receiving'],
            typ=a['character'],
            attr=a['female'],
            value=a['true']
        )
        for character in character_neighbors:
            label = character[1][a['casta']]
            female_characters_receiving_violence_by_casta.setdefault(label, [])
            female_characters_receiving_violence_by_casta[label].append(character)
freq_female_characters_receiving_violence_by_casta = freq_dict(female_characters_receiving_violence_by_casta)

# %%
figure(1, figsize=(6,6))
female_characters_receiving_violence_by_casta_sr = pd.Series(freq_female_characters_receiving_violence_by_casta)
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'w']
plt.pie(female_characters_receiving_violence_by_casta_sr, labels=female_characters_receiving_violence_by_casta_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x15f11450>,
#   <matplotlib.patches.Wedge at 0x15f11f50>,
#   <matplotlib.patches.Wedge at 0x15f15950>,
#   <matplotlib.patches.Wedge at 0x15f17350>,
#   <matplotlib.patches.Wedge at 0x15f17d10>],
#  [<matplotlib.text.Text at 0x15f11c50>,
#   <matplotlib.text.Text at 0x15f15690>,
#   <matplotlib.text.Text at 0x15f17090>,
#   <matplotlib.text.Text at 0x15f17a50>,
#   <matplotlib.text.Text at 0x15f1a450>],
#  [<matplotlib.text.Text at 0x15f11e90>,
#   <matplotlib.text.Text at 0x15f158d0>,
#   <matplotlib.text.Text at 0x15f172d0>,
#   <matplotlib.text.Text at 0x15f17c90>,
#   <matplotlib.text.Text at 0x15f1a690>])

# %% [markdown]
# ### Characters doing violence by casta

# %%
characters_doing_violence_by_casta = {}
for character in characters:
    action_neighbors = node_neighbor_list(
        character[0],
        castas,
        label=a['doing'],
        typ=a['action'],
    )
    for action in action_neighbors:
        if action[1][a['label']] in violent_actions:
            label = character[1][a['casta']]
            characters_doing_violence_by_casta.setdefault(label, [])
            characters_doing_violence_by_casta[label].append(character)
freq_characters_doing_violence_by_casta = freq_dict(characters_doing_violence_by_casta)

# %%
figure(1, figsize=(16,16))
characters_doing_violence_by_casta_sr = pd.Series(freq_characters_doing_violence_by_casta)
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'w']
plt.pie(characters_doing_violence_by_casta_sr, labels=characters_doing_violence_by_casta_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x15f30fd0>,
#   <matplotlib.patches.Wedge at 0x15f34b10>,
#   <matplotlib.patches.Wedge at 0x15f37510>,
#   <matplotlib.patches.Wedge at 0x15f37ed0>,
#   <matplotlib.patches.Wedge at 0x15f3b8d0>,
#   <matplotlib.patches.Wedge at 0x164d82d0>,
#   <matplotlib.patches.Wedge at 0x164d8c90>,
#   <matplotlib.patches.Wedge at 0x164dc690>,
#   <matplotlib.patches.Wedge at 0x164df090>,
#   <matplotlib.patches.Wedge at 0x164dfa50>,
#   <matplotlib.patches.Wedge at 0x164e2450>,
#   <matplotlib.patches.Wedge at 0x164e2e10>,
#   <matplotlib.patches.Wedge at 0x164e5810>,
#   <matplotlib.patches.Wedge at 0x164e8210>,
#   <matplotlib.patches.Wedge at 0x164e8bd0>,
#   <matplotlib.patches.Wedge at 0x164ec5d0>,
#   <matplotlib.patches.Wedge at 0x164ecf90>,
#   <matplotlib.patches.Wedge at 0x164f0990>],
#  [<matplotlib.text.Text at 0x15f34810>,
#   <matplotlib.text.Text at 0x15f37250>,
#   <matplotlib.text.Text at 0x15f37c10>,
#   <matplotlib.text.Text at 0x15f3b610>,
#   <matplotlib.text.Text at 0x15f3bfd0>,
#   <matplotlib.text.Text at 0x164d89d0>,
#   <matplotlib.text.Text at 0x164dc3d0>,
#   <matplotlib.text.Text at 0x164dcd90>,
#   <matplotlib.text.Text at 0x164df790>,
#   <matplotlib.text.Text at 0x164e2190>,
#   <matplotlib.text.Text at 0x164e2b50>,
#   <matplotlib.text.Text at 0x164e5550>,
#   <matplotlib.text.Text at 0x164e5f10>,
#   <matplotlib.text.Text at 0x164e8910>,
#   <matplotlib.text.Text at 0x164ec310>,
#   <matplotlib.text.Text at 0x164eccd0>,
#   <matplotlib.text.Text at 0x164f06d0>,
#   <matplotlib.text.Text at 0x164f30d0>],
#  [<matplotlib.text.Text at 0x15f34a50>,
#   <matplotlib.text.Text at 0x15f37490>,
#   <matplotlib.text.Text at 0x15f37e50>,
#   <matplotlib.text.Text at 0x15f3b850>,
#   <matplotlib.text.Text at 0x164d8250>,
#   <matplotlib.text.Text at 0x164d8c10>,
#   <matplotlib.text.Text at 0x164dc610>,
#   <matplotlib.text.Text at 0x164dced0>,
#   <matplotlib.text.Text at 0x164df9d0>,
#   <matplotlib.text.Text at 0x164e23d0>,
#   <matplotlib.text.Text at 0x164e2d90>,
#   <matplotlib.text.Text at 0x164e5790>,
#   <matplotlib.text.Text at 0x164e81d0>,
#   <matplotlib.text.Text at 0x164e8b50>,
#   <matplotlib.text.Text at 0x164ec550>,
#   <matplotlib.text.Text at 0x164ecf10>,
#   <matplotlib.text.Text at 0x164f0910>,
#   <matplotlib.text.Text at 0x164f3310>])

# %% [markdown]
# ### Male characters doing violence by casta

# %%
male_characters_doing_violence_by_casta = {}
for character in filter_node_dict_by_value(characters, a['male'], a['true']):
    action_neighbors = node_neighbor_list(
        character[0],
        castas,
        label=a['doing'],
        typ=a['action'],
    )
    for action in action_neighbors:
        if action[1][a['label']] in violent_actions:
            label = character[1][a['casta']]
            male_characters_doing_violence_by_casta.setdefault(label, [])
            male_characters_doing_violence_by_casta[label].append(character)
freq_male_characters_doing_violence_by_casta = freq_dict(male_characters_doing_violence_by_casta)

# %%
figure(1, figsize=(10,10))
male_characters_doing_violence_by_casta_sr = pd.Series(freq_male_characters_doing_violence_by_casta)
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'w']
plt.pie(male_characters_doing_violence_by_casta_sr, labels=male_characters_doing_violence_by_casta_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x16516d10>,
#   <matplotlib.patches.Wedge at 0x16665850>,
#   <matplotlib.patches.Wedge at 0x16668250>,
#   <matplotlib.patches.Wedge at 0x16668c10>,
#   <matplotlib.patches.Wedge at 0x1666b610>,
#   <matplotlib.patches.Wedge at 0x1666bfd0>,
#   <matplotlib.patches.Wedge at 0x1666e9d0>,
#   <matplotlib.patches.Wedge at 0x166713d0>,
#   <matplotlib.patches.Wedge at 0x16671d90>,
#   <matplotlib.patches.Wedge at 0x16674790>,
#   <matplotlib.patches.Wedge at 0x16677190>,
#   <matplotlib.patches.Wedge at 0x16677b50>,
#   <matplotlib.patches.Wedge at 0x1667a550>,
#   <matplotlib.patches.Wedge at 0x1667af10>,
#   <matplotlib.patches.Wedge at 0x1667e910>,
#   <matplotlib.patches.Wedge at 0x1667f310>],
#  [<matplotlib.text.Text at 0x16665550>,
#   <matplotlib.text.Text at 0x16665f50>,
#   <matplotlib.text.Text at 0x16668950>,
#   <matplotlib.text.Text at 0x1666b350>,
#   <matplotlib.text.Text at 0x1666bd10>,
#   <matplotlib.text.Text at 0x1666e710>,
#   <matplotlib.text.Text at 0x16671110>,
#   <matplotlib.text.Text at 0x16671ad0>,
#   <matplotlib.text.Text at 0x166744d0>,
#   <matplotlib.text.Text at 0x16674e90>,
#   <matplotlib.text.Text at 0x16677890>,
#   <matplotlib.text.Text at 0x1667a290>,
#   <matplotlib.text.Text at 0x1667ac50>,
#   <matplotlib.text.Text at 0x1667e650>,
#   <matplotlib.text.Text at 0x1667f050>,
#   <matplotlib.text.Text at 0x1667fa10>],
#  [<matplotlib.text.Text at 0x16665790>,
#   <matplotlib.text.Text at 0x166681d0>,
#   <matplotlib.text.Text at 0x16668b90>,
#   <matplotlib.text.Text at 0x1666b590>,
#   <matplotlib.text.Text at 0x1666bf50>,
#   <matplotlib.text.Text at 0x1666e950>,
#   <matplotlib.text.Text at 0x16671350>,
#   <matplotlib.text.Text at 0x16671d10>,
#   <matplotlib.text.Text at 0x16674710>,
#   <matplotlib.text.Text at 0x16674f50>,
#   <matplotlib.text.Text at 0x16677ad0>,
#   <matplotlib.text.Text at 0x1667a4d0>,
#   <matplotlib.text.Text at 0x1667ae90>,
#   <matplotlib.text.Text at 0x1667e890>,
#   <matplotlib.text.Text at 0x1667f290>,
#   <matplotlib.text.Text at 0x1667fc50>])

# %% [markdown]
# ### Female characters doing violence by casta

# %%
female_characters_doing_violence_by_casta = {}
for character in filter_node_dict_by_value(characters, a['female'], a['true']):
    action_neighbors = node_neighbor_list(
        character[0],
        castas,
        label=a['doing'],
        typ=a['action'],
    )
    for action in action_neighbors:
        if action[1][a['label']] in violent_actions:
            label = character[1][a['casta']]
            female_characters_doing_violence_by_casta.setdefault(label, [])
            female_characters_doing_violence_by_casta[label].append(character)
freq_female_characters_doing_violence_by_casta = freq_dict(female_characters_doing_violence_by_casta)

# %%
figure(1, figsize=(10,10))
female_characters_doing_violence_by_casta_sr = pd.Series(freq_female_characters_doing_violence_by_casta)
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'w']
plt.pie(female_characters_doing_violence_by_casta_sr, labels=female_characters_doing_violence_by_casta_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1669f750>,
#   <matplotlib.patches.Wedge at 0x167c5290>,
#   <matplotlib.patches.Wedge at 0x167c5c50>,
#   <matplotlib.patches.Wedge at 0x167c8650>,
#   <matplotlib.patches.Wedge at 0x167ca050>,
#   <matplotlib.patches.Wedge at 0x167caa10>,
#   <matplotlib.patches.Wedge at 0x167ce410>,
#   <matplotlib.patches.Wedge at 0x167cedd0>,
#   <matplotlib.patches.Wedge at 0x167d17d0>,
#   <matplotlib.patches.Wedge at 0x167d51d0>],
#  [<matplotlib.text.Text at 0x1669ff50>,
#   <matplotlib.text.Text at 0x167c5990>,
#   <matplotlib.text.Text at 0x167c8390>,
#   <matplotlib.text.Text at 0x167c8d50>,
#   <matplotlib.text.Text at 0x167ca750>,
#   <matplotlib.text.Text at 0x167ce150>,
#   <matplotlib.text.Text at 0x167ceb10>,
#   <matplotlib.text.Text at 0x167d1510>,
#   <matplotlib.text.Text at 0x167d1ed0>,
#   <matplotlib.text.Text at 0x167d58d0>],
#  [<matplotlib.text.Text at 0x167c51d0>,
#   <matplotlib.text.Text at 0x167c5bd0>,
#   <matplotlib.text.Text at 0x167c85d0>,
#   <matplotlib.text.Text at 0x167c8f90>,
#   <matplotlib.text.Text at 0x167ca990>,
#   <matplotlib.text.Text at 0x167ce390>,
#   <matplotlib.text.Text at 0x167ced50>,
#   <matplotlib.text.Text at 0x167d1750>,
#   <matplotlib.text.Text at 0x167d5190>,
#   <matplotlib.text.Text at 0x167d5b10>])

# %% [markdown]
# ### Characters receiving 'Hitting/Fighting' by casta

# %%
characters_receiving_fighting_by_casta = {}
for action in actions:
    if castas.node[action][a['label']] == a['fighting']:
        character_neighbors = node_neighbor_list(
            action,
            castas,
            label=a['receiving'],
            typ=a['character'],
        )
        for character in character_neighbors:
            label = character[1][a['casta']]
            characters_receiving_fighting_by_casta.setdefault(label, [])
            characters_receiving_fighting_by_casta[label].append(character)
freq_characters_receiving_fighting_by_casta = freq_dict(characters_receiving_fighting_by_casta)

# %%
figure(1, figsize=(10,10))
characters_receiving_fighting_by_casta_sr = pd.Series(freq_characters_receiving_fighting_by_casta)
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'w']
plt.pie(characters_receiving_fighting_by_casta_sr, labels=characters_receiving_fighting_by_casta_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x167f5490>,
#   <matplotlib.patches.Wedge at 0x167f5f90>,
#   <matplotlib.patches.Wedge at 0x167f9990>,
#   <matplotlib.patches.Wedge at 0x167fc390>,
#   <matplotlib.patches.Wedge at 0x167fcd50>,
#   <matplotlib.patches.Wedge at 0x167ff750>,
#   <matplotlib.patches.Wedge at 0x16bb6150>,
#   <matplotlib.patches.Wedge at 0x16bb6b10>,
#   <matplotlib.patches.Wedge at 0x16bba510>,
#   <matplotlib.patches.Wedge at 0x16bbaed0>,
#   <matplotlib.patches.Wedge at 0x16bbc8d0>],
#  [<matplotlib.text.Text at 0x167f5c90>,
#   <matplotlib.text.Text at 0x167f96d0>,
#   <matplotlib.text.Text at 0x167fc0d0>,
#   <matplotlib.text.Text at 0x167fca90>,
#   <matplotlib.text.Text at 0x167ff490>,
#   <matplotlib.text.Text at 0x167ffe50>,
#   <matplotlib.text.Text at 0x16bb6850>,
#   <matplotlib.text.Text at 0x16bba250>,
#   <matplotlib.text.Text at 0x16bbac10>,
#   <matplotlib.text.Text at 0x16bbc610>,
#   <matplotlib.text.Text at 0x16bbcfd0>],
#  [<matplotlib.text.Text at 0x167f5ed0>,
#   <matplotlib.text.Text at 0x167f9910>,
#   <matplotlib.text.Text at 0x167fc310>,
#   <matplotlib.text.Text at 0x167fccd0>,
#   <matplotlib.text.Text at 0x167ff6d0>,
#   <matplotlib.text.Text at 0x167fff10>,
#   <matplotlib.text.Text at 0x16bb6a90>,
#   <matplotlib.text.Text at 0x16bba490>,
#   <matplotlib.text.Text at 0x16bbae50>,
#   <matplotlib.text.Text at 0x16bbc850>,
#   <matplotlib.text.Text at 0x16bc0250>])

# %% [markdown]
# ### Characters doing 'Hitting/Fighting' by casta

# %%
characters_doing_fighting_by_casta = {}
for character in characters:
    action_neighbors = node_neighbor_list(
        character[0],
        castas,
        label=a['doing'],
        typ=a['action'],
    )
    for action in action_neighbors:
        if action[1][a['label']] == a['fighting']:
            label = character[1][a['casta']]
            characters_doing_fighting_by_casta.setdefault(label, [])
            characters_doing_fighting_by_casta[label].append(character)
freq_characters_doing_fighting_by_casta = freq_dict(characters_doing_fighting_by_casta)

# %%
figure(1, figsize=(10,10))
characters_doing_fighting_by_casta_sr = pd.Series(freq_characters_doing_fighting_by_casta)
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'w']
plt.pie(characters_doing_fighting_by_casta_sr, labels=characters_doing_fighting_by_casta_sr.keys(), autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x16bdbd10>,
#   <matplotlib.patches.Wedge at 0x16be0850>,
#   <matplotlib.patches.Wedge at 0x16be3250>,
#   <matplotlib.patches.Wedge at 0x16be3c10>,
#   <matplotlib.patches.Wedge at 0x16be7610>,
#   <matplotlib.patches.Wedge at 0x16be7fd0>,
#   <matplotlib.patches.Wedge at 0x16bea9d0>,
#   <matplotlib.patches.Wedge at 0x16bee3d0>,
#   <matplotlib.patches.Wedge at 0x16beed90>,
#   <matplotlib.patches.Wedge at 0x16bf1790>,
#   <matplotlib.patches.Wedge at 0x16bf4190>],
#  [<matplotlib.text.Text at 0x16be0550>,
#   <matplotlib.text.Text at 0x16be0f50>,
#   <matplotlib.text.Text at 0x16be3950>,
#   <matplotlib.text.Text at 0x16be7350>,
#   <matplotlib.text.Text at 0x16be7d10>,
#   <matplotlib.text.Text at 0x16bea710>,
#   <matplotlib.text.Text at 0x16bee110>,
#   <matplotlib.text.Text at 0x16beead0>,
#   <matplotlib.text.Text at 0x16bf14d0>,
#   <matplotlib.text.Text at 0x16bf1e90>,
#   <matplotlib.text.Text at 0x16bf4890>],
#  [<matplotlib.text.Text at 0x16be0790>,
#   <matplotlib.text.Text at 0x16be31d0>,
#   <matplotlib.text.Text at 0x16be3b90>,
#   <matplotlib.text.Text at 0x16be7590>,
#   <matplotlib.text.Text at 0x16be7f50>,
#   <matplotlib.text.Text at 0x16bea950>,
#   <matplotlib.text.Text at 0x16bee350>,
#   <matplotlib.text.Text at 0x16beed10>,
#   <matplotlib.text.Text at 0x16bf1710>,
#   <matplotlib.text.Text at 0x16bf1f50>,
#   <matplotlib.text.Text at 0x16bf4ad0>])
